# %%
# based on Deep Learning Illustrated by Jon Krohn
# https://www.amazon.com/Deep-Learning-Illustrated-Intelligence-Addison-Wesley/dp/0135116694
# in turn based on bit.ly/keonDQN

import os
from collections import deque
import random
import time
import resource

import pdb

import numpy as np
import pandas as pd

from tensorflow import keras
from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# requires python 3.6
# conda install -c akode gym
import gym

# %%
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.learning_rate = 0.001
        self.model = self.build_model()
        self.memory = pd.DataFrame(columns=["state", "action", "next_state", "reward", "done"])
        
    def build_model(self,
                    n_hidden_layers=2, 
                    hidden_layer_size=32, 
                    activation='relu',
                    reg_penalty=0.0,
                    dropout=False,
                    verbose=True
                   ):
        """return keras NN model per inputs
        input is a state - array of size state_size
        output is an array of action values - array of size action_size
        """

        model = Sequential()

        for i in range(n_hidden_layers):
            if verbose:
                print("layer %d size %d, %s, reg_penalty %.8f, dropout %.3f" % (i + 1, 
                                                                                hidden_layer_size, 
                                                                                activation,
                                                                                reg_penalty,
                                                                                dropout,
                                                                               ))
            # add dropout, but not on inputs, only between hidden layers
            if i and dropout:
                model.add(Dropout(dropout))

            if i==0: # first layer, specify input shape
                model.add(Dense(input_shape=(state_size,),
                                units = hidden_layer_size, 
                                activation = activation,
                                kernel_initializer = keras.initializers.glorot_uniform(),
                                kernel_regularizer=keras.regularizers.l2(reg_penalty),
                                name = "Dense%02d" % i))
            else: #use implicit input shape
                model.add(Dense(units = hidden_layer_size, 
                                activation = activation,
                                kernel_initializer = keras.initializers.glorot_uniform(),
                                kernel_regularizer=keras.regularizers.l2(reg_penalty),
                                name = "Dense%02d" % i))

        model.add(Dense(self.action_size, activation='linear'))

        if verbose:
            print(model.summary())

        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))

        return model
        
    def remember(self, state, action, reward, next_state, done):
        # append in place
        self.memory.loc[self.memory.shape[0]]=[state[0], action, next_state[0], reward, done]
        # TODO: eventually truncate last 2000
        
    def mem_predict_state(row, action):
        state = np.array([[row['state_00'],
                           row['state_01'],
                           row['state_02'],
                           row['state_03'],
                          ]])
        target_f = self.model.predict(state)
        target_f[0][action] = target

        return self.model.predict(state)

    def mem_predict_next_state(row):
        next_state = np.array([[row['next_state_00'],
                                row['next_state_01'],
                                row['next_state_02'],
                                row['next_state_03'],
                               ]])
        return np.amax(self.model.predict(next_state)[0])
    
    def train(self, batch_size):
        # get batch_size observations from memory
        minibatch = self.memory[-2000:].sample(n=batch_size)
        
        # target is best prediction of value of each action
        X_fit = np.concatenate(minibatch['state'].values)
        X_fit = X_fit.reshape((batch_size, self.state_size))
        Y_pred = self.model.predict(X_fit)

        # we don't just fit against our own prediction, that gets us nowhere
        # we improve the target by what we learned about the action we actually took
        # value is reward + predicted value of the observed next state
        minibatch['target_observed'] = minibatch['reward']
        not_done = minibatch.loc[minibatch['done'] == False]
        X_observed = np.concatenate(not_done['next_state'].values)
        X_observed = X_observed.reshape((not_done.shape[0], self.state_size))
        y_observed_pred = np.amax(self.model.predict(X_observed), axis=1)
        minibatch.loc[minibatch['done'] == False, 'target_observed'] += self.gamma * y_observed_pred
        np.put_along_axis(Y_pred, 
                          minibatch['action'].astype(int).values.reshape(batch_size,1), 
                          minibatch['target_observed'].values.reshape(batch_size,1),
                          axis=1)
        # fit model against improved target
        self.model.fit(X_fit, Y_pred, epochs=1, batch_size=1, verbose=0)
        
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
            
    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])
    
    def load(self, filename):
        with open('%s.json' % filename, 'r') as json_file:
            self.model = model_from_json(json_file.read())
        self.model.load_weights("%s.h5" % filename)

    def save(self, filename):
        # serialize model to JSON
        with open("%s.json" % filename, "w") as json_file:
            json_file.write(self.model.to_json())
        # serialize weights to HDF5
        self.model.save_weights("%s.h5" % filename)

# %%
#https://gym.openai.com/envs/CartPole-v0/
env = gym.make('CartPole-v0')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
batch_size = 32
n_episodes=1000
output_dir = 'model_output/cartpole/'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# /Users/druce/anaconda3/envs/python36/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %%
agent = DQNAgent(state_size, action_size)

for e in range(n_episodes):
    print ('Memory usage: %s (kb)' % resource.getrusage(resource.RUSAGE_SELF).ru_maxrss)
    
    state = env.reset()
    state = np.reshape(state, [1, state_size])
    done = False
    timesteps = 0
    
    while not done:
        env.render()
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        reward = reward if not done else -10
        next_state = next_state.reshape([1, state_size])
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        if done:
            print("{} episode: {}/{}, score: {}, epsilon: {:.02}"
                  .format(time.strftime("%H:%M:%S"), e, n_episodes, timesteps, agent.epsilon))
        timesteps +=1
    if len(agent.memory) > batch_size:
        #pdb.set_trace()
        agent.train(batch_size)
    if e % 10 == 0:
        agent.save(output_dir + "model_%.04d" % e)
# Out:
# layer 1 size 32, relu, reg_penalty 0.00000000, dropout 0.000
# layer 2 size 32, relu, reg_penalty 0.00000000, dropout 0.000
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Dense00 (Dense)              (None, 32)                160
# _________________________________________________________________
# Dense01 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense (Dense)                (None, 2)                 66
# =================================================================
# Total params: 1,282
# Trainable params: 1,282
# Non-trainable params: 0
# _________________________________________________________________
# None
# Memory usage: 222085120 (kb)
# 11:18:24 episode: 0/1000, score: 16, epsilon: 1.0
# Memory usage: 266989568 (kb)
# 11:18:25 episode: 1/1000, score: 10, epsilon: 1.0
# Memory usage: 267022336 (kb)
# 11:18:25 episode: 2/1000, score: 10, epsilon: 1.0
# Memory usage: 288722944 (kb)
# 11:18:26 episode: 3/1000, score: 36, epsilon: 0.99
# Memory usage: 290672640 (kb)
# 11:18:27 episode: 4/1000, score: 8, epsilon: 0.99
# Memory usage: 292663296 (kb)
# 11:18:27 episode: 5/1000, score: 11, epsilon: 0.99
# Memory usage: 294797312 (kb)
# 11:18:28 episode: 6/1000, score: 7, epsilon: 0.98
# Memory usage: 296288256 (kb)
# 11:18:28 episode: 7/1000, score: 14, epsilon: 0.98
# Memory usage: 297779200 (kb)
# 11:18:28 episode: 8/1000, score: 19, epsilon: 0.97
# Memory usage: 300621824 (kb)
# 11:18:29 episode: 9/1000, score: 14, epsilon: 0.97
# Memory usage: 303693824 (kb)
# 11:18:29 episode: 10/1000, score: 42, epsilon: 0.96
# Memory usage: 305291264 (kb)
# 11:18:30 episode: 11/1000, score: 47, epsilon: 0.96
# Memory usage: 308183040 (kb)
# 11:18:31 episode: 12/1000, score: 10, epsilon: 0.95
# Memory usage: 311410688 (kb)
# 11:18:31 episode: 13/1000, score: 15, epsilon: 0.95
# Memory usage: 313032704 (kb)
# 11:18:32 episode: 14/1000, score: 32, epsilon: 0.94
# Memory usage: 315912192 (kb)
# 11:18:32 episode: 15/1000, score: 13, epsilon: 0.94
# Memory usage: 317767680 (kb)
# 11:18:32 episode: 16/1000, score: 23, epsilon: 0.93
# Memory usage: 320196608 (kb)
# 11:18:33 episode: 17/1000, score: 9, epsilon: 0.93
# Memory usage: 322531328 (kb)
# 11:18:33 episode: 18/1000, score: 40, epsilon: 0.92
# Memory usage: 327008256 (kb)
# 11:18:34 episode: 19/1000, score: 12, epsilon: 0.92
# Memory usage: 329150464 (kb)
# 11:18:34 episode: 20/1000, score: 12, epsilon: 0.91
# Memory usage: 330977280 (kb)
# 11:18:35 episode: 21/1000, score: 25, epsilon: 0.91
# Memory usage: 333832192 (kb)
# 11:18:35 episode: 22/1000, score: 22, epsilon: 0.9
# Memory usage: 337006592 (kb)
# 11:18:36 episode: 23/1000, score: 21, epsilon: 0.9
# Memory usage: 339345408 (kb)
# 11:18:36 episode: 24/1000, score: 29, epsilon: 0.9
# Memory usage: 342630400 (kb)
# 11:18:37 episode: 25/1000, score: 13, epsilon: 0.89
# Memory usage: 344526848 (kb)
# 11:18:37 episode: 26/1000, score: 16, epsilon: 0.89
# Memory usage: 347684864 (kb)
# 11:18:38 episode: 27/1000, score: 15, epsilon: 0.88
# Memory usage: 351064064 (kb)
# 11:18:38 episode: 28/1000, score: 16, epsilon: 0.88
# Memory usage: 354172928 (kb)
# 11:18:39 episode: 29/1000, score: 9, epsilon: 0.87
# Memory usage: 356388864 (kb)
# 11:18:39 episode: 30/1000, score: 9, epsilon: 0.87
# Memory usage: 358158336 (kb)
# 11:18:40 episode: 31/1000, score: 20, epsilon: 0.86
# Memory usage: 361451520 (kb)
# 11:18:40 episode: 32/1000, score: 22, epsilon: 0.86
# Memory usage: 365588480 (kb)
# 11:18:41 episode: 33/1000, score: 10, epsilon: 0.86
# Memory usage: 368705536 (kb)
# 11:18:41 episode: 34/1000, score: 8, epsilon: 0.85
# Memory usage: 370262016 (kb)
# 11:18:42 episode: 35/1000, score: 17, epsilon: 0.85
# Memory usage: 373972992 (kb)
# 11:18:42 episode: 36/1000, score: 25, epsilon: 0.84
# Memory usage: 377716736 (kb)
# 11:18:43 episode: 37/1000, score: 23, epsilon: 0.84
# Memory usage: 380841984 (kb)
# 11:18:43 episode: 38/1000, score: 13, epsilon: 0.83
# Memory usage: 384282624 (kb)
# 11:18:44 episode: 39/1000, score: 19, epsilon: 0.83
# Memory usage: 386568192 (kb)
# 11:18:45 episode: 40/1000, score: 37, epsilon: 0.83
# Memory usage: 392204288 (kb)
# 11:18:45 episode: 41/1000, score: 18, epsilon: 0.82
# Memory usage: 396390400 (kb)
# 11:18:46 episode: 42/1000, score: 20, epsilon: 0.82
# Memory usage: 402243584 (kb)
# 11:18:47 episode: 43/1000, score: 30, epsilon: 0.81
# Memory usage: 408780800 (kb)
# 11:18:48 episode: 44/1000, score: 14, epsilon: 0.81
# Memory usage: 411631616 (kb)
# 11:18:48 episode: 45/1000, score: 16, epsilon: 0.81
# Memory usage: 415268864 (kb)
# 11:18:49 episode: 46/1000, score: 8, epsilon: 0.8
# Memory usage: 417665024 (kb)
# 11:18:49 episode: 47/1000, score: 17, epsilon: 0.8
# Memory usage: 420610048 (kb)
# 11:18:50 episode: 48/1000, score: 12, epsilon: 0.79
# Memory usage: 424374272 (kb)
# 11:18:50 episode: 49/1000, score: 11, epsilon: 0.79
# Memory usage: 426627072 (kb)
# 11:18:51 episode: 50/1000, score: 11, epsilon: 0.79
# Memory usage: 429121536 (kb)
# 11:18:51 episode: 51/1000, score: 12, epsilon: 0.78
# Memory usage: 433639424 (kb)
# 11:18:52 episode: 52/1000, score: 25, epsilon: 0.78
# Memory usage: 441049088 (kb)
# 11:18:53 episode: 53/1000, score: 29, epsilon: 0.77
# Memory usage: 446021632 (kb)
# 11:18:54 episode: 54/1000, score: 39, epsilon: 0.77
# Memory usage: 451125248 (kb)
# 11:18:55 episode: 55/1000, score: 17, epsilon: 0.77
# Memory usage: 455589888 (kb)
# 11:18:56 episode: 56/1000, score: 51, epsilon: 0.76
# Memory usage: 465960960 (kb)
# 11:18:57 episode: 57/1000, score: 30, epsilon: 0.76
# Memory usage: 470827008 (kb)
# 11:18:58 episode: 58/1000, score: 17, epsilon: 0.76
# Memory usage: 475213824 (kb)
# 11:18:59 episode: 59/1000, score: 24, epsilon: 0.75
# Memory usage: 482668544 (kb)
# 11:19:00 episode: 60/1000, score: 39, epsilon: 0.75
# Memory usage: 489725952 (kb)
# 11:19:00 episode: 61/1000, score: 17, epsilon: 0.74
# Memory usage: 494190592 (kb)
# 11:19:01 episode: 62/1000, score: 24, epsilon: 0.74
# Memory usage: 498860032 (kb)
# 11:19:02 episode: 63/1000, score: 49, epsilon: 0.74
# Memory usage: 505888768 (kb)
# 11:19:04 episode: 64/1000, score: 62, epsilon: 0.73
# Memory usage: 516198400 (kb)
# 11:19:05 episode: 65/1000, score: 19, epsilon: 0.73
# Memory usage: 522477568 (kb)
# 11:19:06 episode: 66/1000, score: 28, epsilon: 0.73
# Memory usage: 529100800 (kb)
# 11:19:07 episode: 67/1000, score: 26, epsilon: 0.72
# Memory usage: 535203840 (kb)
# 11:19:07 episode: 68/1000, score: 20, epsilon: 0.72
# Memory usage: 539537408 (kb)
# 11:19:08 episode: 69/1000, score: 13, epsilon: 0.71
# Memory usage: 543666176 (kb)
# 11:19:09 episode: 70/1000, score: 33, epsilon: 0.71
# Memory usage: 551587840 (kb)
# 11:19:10 episode: 71/1000, score: 18, epsilon: 0.71
# Memory usage: 557170688 (kb)
# 11:19:10 episode: 72/1000, score: 18, epsilon: 0.7
# Memory usage: 563060736 (kb)
# 11:19:11 episode: 73/1000, score: 25, epsilon: 0.7
# Memory usage: 568610816 (kb)
# 11:19:12 episode: 74/1000, score: 10, epsilon: 0.7
# Memory usage: 570744832 (kb)
# 11:19:12 episode: 75/1000, score: 7, epsilon: 0.69
# Memory usage: 572690432 (kb)
# 11:19:13 episode: 76/1000, score: 23, epsilon: 0.69
# Memory usage: 578617344 (kb)
# 11:19:15 episode: 77/1000, score: 52, epsilon: 0.69
# Memory usage: 589176832 (kb)
# 11:19:16 episode: 78/1000, score: 23, epsilon: 0.68
# Memory usage: 599212032 (kb)
# 11:19:18 episode: 79/1000, score: 64, epsilon: 0.68
# Memory usage: 614268928 (kb)
# 11:19:20 episode: 80/1000, score: 63, epsilon: 0.68
# Memory usage: 631238656 (kb)
# 11:19:21 episode: 81/1000, score: 39, epsilon: 0.67
# Memory usage: 640040960 (kb)
# 11:19:22 episode: 82/1000, score: 17, epsilon: 0.67
# Memory usage: 644775936 (kb)
# 11:19:23 episode: 83/1000, score: 21, epsilon: 0.67
# Memory usage: 651268096 (kb)
# 11:19:24 episode: 84/1000, score: 9, epsilon: 0.66
# Memory usage: 656773120 (kb)
# 11:19:25 episode: 85/1000, score: 13, epsilon: 0.66
# Memory usage: 660381696 (kb)
# 11:19:25 episode: 86/1000, score: 8, epsilon: 0.66
# Memory usage: 664526848 (kb)
# 11:19:26 episode: 87/1000, score: 10, epsilon: 0.65
# Memory usage: 668459008 (kb)
# 11:19:26 episode: 88/1000, score: 9, epsilon: 0.65
# Memory usage: 672538624 (kb)
# 11:19:27 episode: 89/1000, score: 32, epsilon: 0.65
# Memory usage: 678285312 (kb)
# 11:19:29 episode: 90/1000, score: 35, epsilon: 0.64
# Memory usage: 688353280 (kb)
# 11:19:30 episode: 91/1000, score: 23, epsilon: 0.64
# Memory usage: 695607296 (kb)
# 11:19:30 episode: 92/1000, score: 29, epsilon: 0.64
# Memory usage: 702361600 (kb)
# 11:19:31 episode: 93/1000, score: 29, epsilon: 0.63
# Memory usage: 709660672 (kb)
# 11:19:32 episode: 94/1000, score: 10, epsilon: 0.63
# Memory usage: 713105408 (kb)
# 11:19:33 episode: 95/1000, score: 13, epsilon: 0.63
# Memory usage: 717443072 (kb)
# 11:19:34 episode: 96/1000, score: 25, epsilon: 0.62
# Memory usage: 725909504 (kb)
# 11:19:35 episode: 97/1000, score: 40, epsilon: 0.62
# Memory usage: 737583104 (kb)
# 11:19:38 episode: 98/1000, score: 61, epsilon: 0.62
# Memory usage: 756133888 (kb)
# 11:19:39 episode: 99/1000, score: 31, epsilon: 0.61
# Memory usage: 763990016 (kb)
# 11:19:40 episode: 100/1000, score: 13, epsilon: 0.61
# Memory usage: 767545344 (kb)
# 11:19:40 episode: 101/1000, score: 12, epsilon: 0.61
# Memory usage: 771518464 (kb)
# 11:19:42 episode: 102/1000, score: 31, epsilon: 0.61
# Memory usage: 779866112 (kb)
# 11:19:42 episode: 103/1000, score: 14, epsilon: 0.6
# Memory usage: 785522688 (kb)
# 11:19:43 episode: 104/1000, score: 22, epsilon: 0.6
# Memory usage: 793866240 (kb)
# 11:19:45 episode: 105/1000, score: 24, epsilon: 0.6
# Memory usage: 804229120 (kb)
# 11:19:46 episode: 106/1000, score: 18, epsilon: 0.59
# Memory usage: 811020288 (kb)
# 11:19:47 episode: 107/1000, score: 17, epsilon: 0.59
# Memory usage: 814694400 (kb)
# 11:19:47 episode: 108/1000, score: 11, epsilon: 0.59
# Memory usage: 818569216 (kb)
# 11:19:48 episode: 109/1000, score: 9, epsilon: 0.58
# Memory usage: 822259712 (kb)
# 11:19:48 episode: 110/1000, score: 11, epsilon: 0.58
# Memory usage: 827265024 (kb)
# 11:19:50 episode: 111/1000, score: 44, epsilon: 0.58
# Memory usage: 840880128 (kb)
# 11:19:51 episode: 112/1000, score: 9, epsilon: 0.58
# Memory usage: 843243520 (kb)
# 11:19:51 episode: 113/1000, score: 10, epsilon: 0.57
# Memory usage: 846200832 (kb)
# 11:19:52 episode: 114/1000, score: 22, epsilon: 0.57
# Memory usage: 852574208 (kb)
# 11:19:53 episode: 115/1000, score: 16, epsilon: 0.57
# Memory usage: 857210880 (kb)
# 11:19:53 episode: 116/1000, score: 16, epsilon: 0.56
# Memory usage: 863125504 (kb)
# 11:19:55 episode: 117/1000, score: 60, epsilon: 0.56
# Memory usage: 878579712 (kb)
# 11:19:59 episode: 118/1000, score: 69, epsilon: 0.56
# Memory usage: 898646016 (kb)
# 11:20:01 episode: 119/1000, score: 54, epsilon: 0.56
# Memory usage: 918945792 (kb)
# 11:20:03 episode: 120/1000, score: 43, epsilon: 0.55
# Memory usage: 933507072 (kb)
# 11:20:05 episode: 121/1000, score: 45, epsilon: 0.55
# Memory usage: 951214080 (kb)
# 11:20:08 episode: 122/1000, score: 73, epsilon: 0.55
# Memory usage: 974856192 (kb)
# 11:20:09 episode: 123/1000, score: 29, epsilon: 0.55
# Memory usage: 983519232 (kb)
# 11:20:11 episode: 124/1000, score: 33, epsilon: 0.54
# Memory usage: 993824768 (kb)
# 11:20:12 episode: 125/1000, score: 34, epsilon: 0.54
# Memory usage: 1004449792 (kb)
# 11:20:15 episode: 126/1000, score: 62, epsilon: 0.54
# Memory usage: 1024765952 (kb)
# 11:20:15 episode: 127/1000, score: 16, epsilon: 0.53
# Memory usage: 1030275072 (kb)
# 11:20:17 episode: 128/1000, score: 36, epsilon: 0.53
# Memory usage: 1044426752 (kb)
# 11:20:22 episode: 129/1000, score: 96, epsilon: 0.53
# Memory usage: 1072263168 (kb)
# 11:20:24 episode: 130/1000, score: 61, epsilon: 0.53
# Memory usage: 1092337664 (kb)
# 11:20:29 episode: 131/1000, score: 89, epsilon: 0.52
# Memory usage: 1129029632 (kb)
# 11:20:31 episode: 132/1000, score: 39, epsilon: 0.52
# Memory usage: 1145507840 (kb)
# 11:20:33 episode: 133/1000, score: 47, epsilon: 0.52
# Memory usage: 1163874304 (kb)
# 11:20:34 episode: 134/1000, score: 15, epsilon: 0.52
# Memory usage: 1170448384 (kb)
# 11:20:35 episode: 135/1000, score: 26, epsilon: 0.51
# Memory usage: 1179283456 (kb)
# 11:20:37 episode: 136/1000, score: 35, epsilon: 0.51
# Memory usage: 1191923712 (kb)
# 11:20:38 episode: 137/1000, score: 18, epsilon: 0.51
# Memory usage: 1198702592 (kb)
# 11:20:39 episode: 138/1000, score: 22, epsilon: 0.51
# Memory usage: 1209278464 (kb)
# 11:20:41 episode: 139/1000, score: 34, epsilon: 0.5
# Memory usage: 1221554176 (kb)
# 11:20:42 episode: 140/1000, score: 23, epsilon: 0.5
# Memory usage: 1230491648 (kb)
# 11:20:43 episode: 141/1000, score: 21, epsilon: 0.5
# Memory usage: 1239932928 (kb)
# 11:20:46 episode: 142/1000, score: 25, epsilon: 0.5
# Memory usage: 1250258944 (kb)
# 11:20:46 episode: 143/1000, score: 10, epsilon: 0.49
# Memory usage: 1254412288 (kb)
# 11:20:50 episode: 144/1000, score: 82, epsilon: 0.49
# Memory usage: 1271607296 (kb)
# 11:20:54 episode: 145/1000, score: 76, epsilon: 0.49
# Memory usage: 1294098432 (kb)
# 11:20:56 episode: 146/1000, score: 56, epsilon: 0.49
# Memory usage: 1309483008 (kb)
# 11:20:59 episode: 147/1000, score: 59, epsilon: 0.48
# Memory usage: 1319170048 (kb)
# 11:21:01 episode: 148/1000, score: 47, epsilon: 0.48
# Memory usage: 1324285952 (kb)
# 11:21:02 episode: 149/1000, score: 20, epsilon: 0.48
# Memory usage: 1324285952 (kb)
# 11:21:07 episode: 150/1000, score: 132, epsilon: 0.48
# Memory usage: 1346785280 (kb)
# 11:21:08 episode: 151/1000, score: 20, epsilon: 0.47
# Memory usage: 1346785280 (kb)
# 11:21:10 episode: 152/1000, score: 50, epsilon: 0.47
# Memory usage: 1346785280 (kb)
# 11:21:12 episode: 153/1000, score: 35, epsilon: 0.47
# Memory usage: 1346785280 (kb)
# 11:21:15 episode: 154/1000, score: 56, epsilon: 0.47
# Memory usage: 1346785280 (kb)
# 11:21:16 episode: 155/1000, score: 30, epsilon: 0.46
# Memory usage: 1346785280 (kb)
# 11:21:19 episode: 156/1000, score: 31, epsilon: 0.46
# Memory usage: 1346785280 (kb)
# 11:21:22 episode: 157/1000, score: 61, epsilon: 0.46
# Memory usage: 1346785280 (kb)
# 11:21:24 episode: 158/1000, score: 44, epsilon: 0.46
# Memory usage: 1346785280 (kb)
# 11:21:27 episode: 159/1000, score: 51, epsilon: 0.46
# Memory usage: 1346785280 (kb)
# 11:21:29 episode: 160/1000, score: 40, epsilon: 0.45
# Memory usage: 1363488768 (kb)
# 11:21:30 episode: 161/1000, score: 18, epsilon: 0.45
# Memory usage: 1378304000 (kb)
# 11:21:32 episode: 162/1000, score: 44, epsilon: 0.45
# Memory usage: 1394503680 (kb)
# 11:21:33 episode: 163/1000, score: 18, epsilon: 0.45
# Memory usage: 1400737792 (kb)
# 11:21:35 episode: 164/1000, score: 40, epsilon: 0.44
# Memory usage: 1414701056 (kb)
# 11:21:36 episode: 165/1000, score: 33, epsilon: 0.44
# Memory usage: 1427628032 (kb)
# 11:21:38 episode: 166/1000, score: 36, epsilon: 0.44
# Memory usage: 1436667904 (kb)
# 11:21:42 episode: 167/1000, score: 93, epsilon: 0.44
# Memory usage: 1443971072 (kb)
# 11:21:45 episode: 168/1000, score: 65, epsilon: 0.44
# Memory usage: 1465569280 (kb)
# 11:21:45 episode: 169/1000, score: 14, epsilon: 0.43
# Memory usage: 1469558784 (kb)
# 11:21:48 episode: 170/1000, score: 51, epsilon: 0.43
# Memory usage: 1485553664 (kb)
# 11:21:50 episode: 171/1000, score: 38, epsilon: 0.43
# Memory usage: 1494913024 (kb)
# 11:21:51 episode: 172/1000, score: 37, epsilon: 0.43
# Memory usage: 1494913024 (kb)
# 11:21:54 episode: 173/1000, score: 55, epsilon: 0.42
# Memory usage: 1496862720 (kb)
# 11:21:58 episode: 174/1000, score: 58, epsilon: 0.42
# Memory usage: 1502040064 (kb)
# 11:22:00 episode: 175/1000, score: 32, epsilon: 0.42
# Memory usage: 1502040064 (kb)
# 11:22:01 episode: 176/1000, score: 25, epsilon: 0.42
# Memory usage: 1502040064 (kb)
# 11:22:03 episode: 177/1000, score: 29, epsilon: 0.42
# Memory usage: 1502040064 (kb)
# 11:22:05 episode: 178/1000, score: 36, epsilon: 0.41
# Memory usage: 1516396544 (kb)
# 11:22:06 episode: 179/1000, score: 17, epsilon: 0.41
# Memory usage: 1523953664 (kb)
# 11:22:08 episode: 180/1000, score: 36, epsilon: 0.41
# Memory usage: 1539751936 (kb)
# 11:22:10 episode: 181/1000, score: 31, epsilon: 0.41
# Memory usage: 1550139392 (kb)
# 11:22:12 episode: 182/1000, score: 35, epsilon: 0.41
# Memory usage: 1567019008 (kb)
# 11:22:14 episode: 183/1000, score: 29, epsilon: 0.4
# Memory usage: 1580945408 (kb)
# 11:22:16 episode: 184/1000, score: 42, epsilon: 0.4
# Memory usage: 1597468672 (kb)
# 11:22:17 episode: 185/1000, score: 31, epsilon: 0.4
# Memory usage: 1607778304 (kb)
# 11:22:19 episode: 186/1000, score: 43, epsilon: 0.4
# Memory usage: 1622528000 (kb)
# 11:22:23 episode: 187/1000, score: 60, epsilon: 0.4
# Memory usage: 1646579712 (kb)
# 11:22:25 episode: 188/1000, score: 51, epsilon: 0.39
# Memory usage: 1664524288 (kb)
# 11:22:26 episode: 189/1000, score: 14, epsilon: 0.39
# Memory usage: 1671958528 (kb)
# 11:22:28 episode: 190/1000, score: 32, epsilon: 0.39
# Memory usage: 1686396928 (kb)
# 11:22:29 episode: 191/1000, score: 26, epsilon: 0.39
# Memory usage: 1694425088 (kb)
# 11:22:30 episode: 192/1000, score: 18, epsilon: 0.39
# Memory usage: 1703333888 (kb)
# 11:22:36 episode: 193/1000, score: 105, epsilon: 0.38
# Memory usage: 1744826368 (kb)
# 11:22:39 episode: 194/1000, score: 32, epsilon: 0.38
# Memory usage: 1744826368 (kb)
# 11:22:43 episode: 195/1000, score: 83, epsilon: 0.38
# Memory usage: 1744826368 (kb)
# 11:22:45 episode: 196/1000, score: 36, epsilon: 0.38
# Memory usage: 1744826368 (kb)
# 11:22:49 episode: 197/1000, score: 41, epsilon: 0.38
# Memory usage: 1744826368 (kb)
# 11:22:52 episode: 198/1000, score: 54, epsilon: 0.37
# Memory usage: 1744826368 (kb)
# 11:22:54 episode: 199/1000, score: 28, epsilon: 0.37
# Memory usage: 1744826368 (kb)
# 11:22:55 episode: 200/1000, score: 24, epsilon: 0.37
# Memory usage: 1744826368 (kb)
# 11:22:59 episode: 201/1000, score: 61, epsilon: 0.37
# Memory usage: 1744826368 (kb)
# 11:23:01 episode: 202/1000, score: 36, epsilon: 0.37
# Memory usage: 1744826368 (kb)
# 11:23:09 episode: 203/1000, score: 115, epsilon: 0.37
# Memory usage: 1744826368 (kb)
# 11:23:11 episode: 204/1000, score: 34, epsilon: 0.36
# Memory usage: 1744826368 (kb)
# 11:23:13 episode: 205/1000, score: 27, epsilon: 0.36
# Memory usage: 1744826368 (kb)
# 11:23:15 episode: 206/1000, score: 39, epsilon: 0.36
# Memory usage: 1744826368 (kb)
# 11:23:18 episode: 207/1000, score: 43, epsilon: 0.36
# Memory usage: 1744826368 (kb)
# 11:23:19 episode: 208/1000, score: 20, epsilon: 0.36
# Memory usage: 1744826368 (kb)
# 11:23:22 episode: 209/1000, score: 38, epsilon: 0.35
# Memory usage: 1744826368 (kb)
# 11:23:27 episode: 210/1000, score: 68, epsilon: 0.35
# Memory usage: 1744826368 (kb)
# 11:23:29 episode: 211/1000, score: 38, epsilon: 0.35
# Memory usage: 1744826368 (kb)
# 11:23:34 episode: 212/1000, score: 56, epsilon: 0.35
# Memory usage: 1744826368 (kb)
# 11:23:36 episode: 213/1000, score: 32, epsilon: 0.35
# Memory usage: 1744826368 (kb)
# 11:23:40 episode: 214/1000, score: 80, epsilon: 0.35
# Memory usage: 1744826368 (kb)
# 11:23:43 episode: 215/1000, score: 45, epsilon: 0.34
# Memory usage: 1744826368 (kb)
# 11:23:46 episode: 216/1000, score: 31, epsilon: 0.34
# Memory usage: 1744826368 (kb)
# 11:23:47 episode: 217/1000, score: 22, epsilon: 0.34
# Memory usage: 1744826368 (kb)
# 11:23:50 episode: 218/1000, score: 36, epsilon: 0.34
# Memory usage: 1744826368 (kb)
# 11:23:52 episode: 219/1000, score: 16, epsilon: 0.34
# Memory usage: 1744826368 (kb)
# 11:23:53 episode: 220/1000, score: 21, epsilon: 0.34
# Memory usage: 1744826368 (kb)
# 11:23:54 episode: 221/1000, score: 16, epsilon: 0.33
# Memory usage: 1744826368 (kb)
# 11:24:02 episode: 222/1000, score: 81, epsilon: 0.33
# Memory usage: 1940606976 (kb)
# 11:24:06 episode: 223/1000, score: 42, epsilon: 0.33
# Memory usage: 1940606976 (kb)
# 11:24:08 episode: 224/1000, score: 52, epsilon: 0.33
# Memory usage: 1940606976 (kb)
# 11:24:11 episode: 225/1000, score: 53, epsilon: 0.33
# Memory usage: 1940606976 (kb)
# 11:24:17 episode: 226/1000, score: 74, epsilon: 0.33
# Memory usage: 1940606976 (kb)
# 11:24:21 episode: 227/1000, score: 67, epsilon: 0.32
# Memory usage: 1940606976 (kb)
# 11:24:24 episode: 228/1000, score: 57, epsilon: 0.32
# Memory usage: 1940606976 (kb)
# 11:24:28 episode: 229/1000, score: 85, epsilon: 0.32
# Memory usage: 1940606976 (kb)
# 11:24:31 episode: 230/1000, score: 39, epsilon: 0.32
# Memory usage: 1940606976 (kb)
# 11:24:34 episode: 231/1000, score: 42, epsilon: 0.32
# Memory usage: 1940606976 (kb)
# 11:24:40 episode: 232/1000, score: 99, epsilon: 0.32
# Memory usage: 1940606976 (kb)
# 11:24:44 episode: 233/1000, score: 62, epsilon: 0.31
# Memory usage: 1940606976 (kb)
# 11:24:50 episode: 234/1000, score: 100, epsilon: 0.31
# Memory usage: 1940606976 (kb)
# 11:24:56 episode: 235/1000, score: 93, epsilon: 0.31
# Memory usage: 1940606976 (kb)
# 11:25:04 episode: 236/1000, score: 126, epsilon: 0.31
# Memory usage: 1940606976 (kb)
# 11:25:16 episode: 237/1000, score: 199, epsilon: 0.31
# Memory usage: 1940606976 (kb)
# 11:25:23 episode: 238/1000, score: 35, epsilon: 0.31
# Memory usage: 2337280000 (kb)
# 11:25:26 episode: 239/1000, score: 51, epsilon: 0.3
# Memory usage: 2337280000 (kb)
# 11:25:33 episode: 240/1000, score: 119, epsilon: 0.3
# Memory usage: 2368159744 (kb)
# 11:25:37 episode: 241/1000, score: 70, epsilon: 0.3
# Memory usage: 2399739904 (kb)
# 11:25:42 episode: 242/1000, score: 87, epsilon: 0.3
# Memory usage: 2441818112 (kb)
# 11:25:46 episode: 243/1000, score: 62, epsilon: 0.3
# Memory usage: 2462912512 (kb)
# 11:25:51 episode: 244/1000, score: 68, epsilon: 0.3
# Memory usage: 2462912512 (kb)
# 11:25:54 episode: 245/1000, score: 67, epsilon: 0.3
# Memory usage: 2462912512 (kb)
# 11:25:57 episode: 246/1000, score: 36, epsilon: 0.29
# Memory usage: 2462912512 (kb)
# 11:26:00 episode: 247/1000, score: 56, epsilon: 0.29
# Memory usage: 2462912512 (kb)
# 11:26:03 episode: 248/1000, score: 49, epsilon: 0.29
# Memory usage: 2462912512 (kb)
# 11:26:06 episode: 249/1000, score: 35, epsilon: 0.29
# Memory usage: 2462912512 (kb)
# 11:26:11 episode: 250/1000, score: 70, epsilon: 0.29
# Memory usage: 2462912512 (kb)
# 11:26:17 episode: 251/1000, score: 88, epsilon: 0.29
# Memory usage: 2462912512 (kb)
# 11:26:20 episode: 252/1000, score: 59, epsilon: 0.29
# Memory usage: 2462912512 (kb)
# 11:26:32 episode: 253/1000, score: 165, epsilon: 0.28
# Memory usage: 2462912512 (kb)
# 11:26:40 episode: 254/1000, score: 141, epsilon: 0.28
# Memory usage: 2462912512 (kb)
# 11:26:45 episode: 255/1000, score: 71, epsilon: 0.28
# Memory usage: 2462912512 (kb)
# 11:26:50 episode: 256/1000, score: 87, epsilon: 0.28
# Memory usage: 2462912512 (kb)
# 11:26:53 episode: 257/1000, score: 51, epsilon: 0.28
# Memory usage: 2462912512 (kb)
# 11:26:54 episode: 258/1000, score: 24, epsilon: 0.28
# Memory usage: 2462912512 (kb)
# 11:27:06 episode: 259/1000, score: 63, epsilon: 0.28
# Memory usage: 2707185664 (kb)
# 11:27:09 episode: 260/1000, score: 75, epsilon: 0.27
# Memory usage: 2738450432 (kb)
# 11:27:13 episode: 261/1000, score: 48, epsilon: 0.27
# Memory usage: 2748538880 (kb)
# 11:27:15 episode: 262/1000, score: 38, epsilon: 0.27
# Memory usage: 2748538880 (kb)
# 11:27:29 episode: 263/1000, score: 199, epsilon: 0.27
# Memory usage: 2748538880 (kb)
# 11:27:34 episode: 264/1000, score: 87, epsilon: 0.27
# Memory usage: 2748538880 (kb)
# 11:27:40 episode: 265/1000, score: 75, epsilon: 0.27
# Memory usage: 2748538880 (kb)
# 11:27:41 episode: 266/1000, score: 24, epsilon: 0.27
# Memory usage: 2748538880 (kb)
# 11:27:48 episode: 267/1000, score: 100, epsilon: 0.26
# Memory usage: 2748538880 (kb)
# 11:27:50 episode: 268/1000, score: 32, epsilon: 0.26
# Memory usage: 2748538880 (kb)
# 11:27:52 episode: 269/1000, score: 37, epsilon: 0.26
# Memory usage: 2748538880 (kb)
# 11:27:56 episode: 270/1000, score: 40, epsilon: 0.26
# Memory usage: 2748538880 (kb)
# 11:27:59 episode: 271/1000, score: 38, epsilon: 0.26
# Memory usage: 2748538880 (kb)
# 11:28:01 episode: 272/1000, score: 28, epsilon: 0.26
# Memory usage: 2748538880 (kb)
# 11:28:04 episode: 273/1000, score: 48, epsilon: 0.26
# Memory usage: 2748538880 (kb)
# 11:28:08 episode: 274/1000, score: 63, epsilon: 0.26
# Memory usage: 2748538880 (kb)
# 11:28:10 episode: 275/1000, score: 29, epsilon: 0.25
# Memory usage: 2748538880 (kb)
# 11:28:14 episode: 276/1000, score: 47, epsilon: 0.25
# Memory usage: 2748538880 (kb)
# 11:28:16 episode: 277/1000, score: 37, epsilon: 0.25
# Memory usage: 2748538880 (kb)
# 11:28:21 episode: 278/1000, score: 72, epsilon: 0.25
# Memory usage: 2748538880 (kb)
# 11:28:25 episode: 279/1000, score: 62, epsilon: 0.25
# Memory usage: 2748538880 (kb)
# 11:28:29 episode: 280/1000, score: 56, epsilon: 0.25
# Memory usage: 2748538880 (kb)
# 11:28:35 episode: 281/1000, score: 60, epsilon: 0.25
# Memory usage: 2748538880 (kb)
# 11:28:38 episode: 282/1000, score: 43, epsilon: 0.25
# Memory usage: 2748538880 (kb)
# 11:28:41 episode: 283/1000, score: 51, epsilon: 0.24
# Memory usage: 2748538880 (kb)
# 11:28:46 episode: 284/1000, score: 80, epsilon: 0.24
# Memory usage: 2748538880 (kb)
# 11:28:48 episode: 285/1000, score: 29, epsilon: 0.24
# Memory usage: 2748538880 (kb)
# 11:28:51 episode: 286/1000, score: 38, epsilon: 0.24
# Memory usage: 2748538880 (kb)
# 11:28:56 episode: 287/1000, score: 79, epsilon: 0.24
# Memory usage: 2748538880 (kb)
# 11:29:02 episode: 288/1000, score: 93, epsilon: 0.24
# Memory usage: 2748538880 (kb)
# 11:29:25 episode: 289/1000, score: 87, epsilon: 0.24
# Memory usage: 3199062016 (kb)
# 11:29:36 episode: 290/1000, score: 144, epsilon: 0.24
# Memory usage: 3199062016 (kb)
# 11:29:41 episode: 291/1000, score: 87, epsilon: 0.23
# Memory usage: 3199062016 (kb)
# 11:29:50 episode: 292/1000, score: 117, epsilon: 0.23
# Memory usage: 3199062016 (kb)
# 11:30:05 episode: 293/1000, score: 199, epsilon: 0.23
# Memory usage: 3199062016 (kb)
# 11:30:19 episode: 294/1000, score: 199, epsilon: 0.23
# Memory usage: 3199062016 (kb)
# 11:30:32 episode: 295/1000, score: 199, epsilon: 0.23
# Memory usage: 3199062016 (kb)
# 11:30:45 episode: 296/1000, score: 199, epsilon: 0.23
# Memory usage: 3199062016 (kb)
# 11:30:58 episode: 297/1000, score: 199, epsilon: 0.23
# Memory usage: 3199062016 (kb)
# 11:31:07 episode: 298/1000, score: 136, epsilon: 0.23
# Memory usage: 3199062016 (kb)
# 11:31:20 episode: 299/1000, score: 199, epsilon: 0.23
# Memory usage: 3199062016 (kb)
# 11:31:33 episode: 300/1000, score: 199, epsilon: 0.22
# Memory usage: 3199062016 (kb)
# 11:31:46 episode: 301/1000, score: 199, epsilon: 0.22
# Memory usage: 3199062016 (kb)
# 11:32:13 episode: 302/1000, score: 172, epsilon: 0.22
# Memory usage: 3926937600 (kb)
# 11:32:26 episode: 303/1000, score: 199, epsilon: 0.22
# Memory usage: 3926937600 (kb)
# 11:32:38 episode: 304/1000, score: 199, epsilon: 0.22
# Memory usage: 3926937600 (kb)
# 11:32:50 episode: 305/1000, score: 199, epsilon: 0.22
# Memory usage: 3926937600 (kb)
# 11:32:57 episode: 306/1000, score: 103, epsilon: 0.22
# Memory usage: 3926937600 (kb)
# 11:33:06 episode: 307/1000, score: 146, epsilon: 0.22
# Memory usage: 3926937600 (kb)
